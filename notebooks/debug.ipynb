# %%
# %autoreload 2

import logging

from game_driver import GameEngine

# Configure logging for notebook
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    datefmt='%H:%M:%S',
)
logger = logging.getLogger(__name__)

engine = GameEngine()
# Out:
# 22:11:21 - INFO - Connected to device: {'serialno': '29131FDH200FJQ', 'devpath': 'usb:3-0', 'state': 'device'}
# 22:11:21 - WARNING - Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# 22:11:27 - INFO - Download complete
# 22:11:27 - WARNING - Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# 22:11:28 - INFO - Download complete.
# 22:11:31 - INFO - Screenshot taken: 1080x2400 -> 460x1024
# /Users/chunzhang/game_driver/.venv/lib/python3.13/site-packages/torch/utils/data/dataloader.py:684: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)

# %%
engine.refresh()
display(engine.debug())
# Out:
# 22:11:40 - INFO - Screenshot taken: 1080x2400 -> 460x1024
# <PIL.Image.Image image mode=RGB size=460x1024>

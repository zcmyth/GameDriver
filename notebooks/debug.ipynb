# %%
# %load_ext autoreload
# %autoreload 2
import logging

from game_driver import GameEngine

# Configure logging for notebook
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    datefmt='%H:%M:%S',
)
logger = logging.getLogger(__name__)
logger.info('started')

engine = GameEngine()
# Out:
# Creating model: ('PP-OCRv5_mobile_det', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `/Users/chunzhang/.paddlex/official_models/PP-OCRv5_mobile_det`.
# Creating model: ('en_PP-OCRv5_mobile_rec', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `/Users/chunzhang/.paddlex/official_models/en_PP-OCRv5_mobile_rec`.
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
engine.refresh()
display(engine.debug())
# Out:
# <PIL.Image.Image image mode=RGB size=460x1024>

# %%
# %load_ext autoreload
# %autoreload 2
import logging

from game_driver import GameEngine

# Configure logging for notebook
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    datefmt='%H:%M:%S',
)
logger = logging.getLogger(__name__)
logger.info('started')

engine = GameEngine()

# %%
engine.refresh()
display(engine.debug())
engine.click_text('drone')
# Out:
# <PIL.Image.Image image mode=RGB size=460x1024>
